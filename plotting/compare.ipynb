# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from plotters import PARAMS, plot_emittances_and_momentum_spread_evolution

plt.rcParams.update(PARAMS)
# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# ### Plotting Old Michalis Data

# %%
michalis_kinetic = pd.read_parquet("../outputs/xsuite_kinetic.parquet")
michalis_simple = pd.read_parquet("../outputs/xsuite_simple.parquet")
michalis_analytical = pd.read_parquet("../outputs/xsuite_analytical.parquet")

# %%
figure = plot_emittances_and_momentum_spread_evolution(
    michalis_kinetic.eps_x.to_numpy(),
    michalis_kinetic.eps_y.to_numpy(),
    michalis_kinetic.sig_delta.to_numpy(),
    michalis_simple.eps_x.to_numpy(),
    michalis_simple.eps_y.to_numpy(),
    michalis_simple.sig_delta.to_numpy(),
    michalis_analytical.eps_x.to_numpy(),
    michalis_analytical.eps_y.to_numpy(),
    michalis_analytical.sig_delta.to_numpy(),
)
# figure.suptitle("Plotting Old Data from Michalis")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/qh/_90_vgwx2v9020gsml9y554r0000gn/T/ipykernel_95258/2896297336.py:13: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# ### Plotting Results of New Code

# %%
with np.load("../outputs/xsuite_kinetic.npz") as data:
    kinetic_epsx = data["epsilon_x"]
    kinetic_epsy = data["epsilon_y"]
    kinetic_sig_delta = data["sig_delta"]

with np.load("../outputs/xsuite_simple.npz") as data:
    simple_epsx = data["epsilon_x"]
    simple_epsy = data["epsilon_y"]
    simple_sig_delta = data["sig_delta"]

with np.load("../outputs/xsuite_analytical.npz") as data:
    analytical_epsx = data["epsilon_x"]
    analytical_epsy = data["epsilon_y"]
    analytical_sig_delta = data["sig_delta"]
